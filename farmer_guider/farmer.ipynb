# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/JECRC-20april2024/main/farmer.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.to_csv('farmer.csv',index=False)

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
group=df.groupby('label')

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
group[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
df['label'].nunique()
# Out:
# 22

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
nitrogen=group['N'].agg(min_nitro='min',max_nitro='max',avg_nitro='mean')

# %%
nitrogen
# Out:
#              min_nitro  max_nitro  avg_nitro
# label
# apple                0         40      20.80
# banana              80        120     100.23
# blackgram           20         60      40.02
# chickpea            20         60      40.09
# coconut              0         40      21.98
# coffee              80        120     101.20
# cotton             100        140     117.77
# grapes               0         40      23.18
# jute                60        100      78.40
# kidneybeans          0         40      20.75
# lentil               0         40      18.77
# maize               60        100      77.76
# mango                0         40      20.07
# mothbeans            0         40      21.44
# mungbean             0         40      20.99
# muskmelon           80        120     100.32
# orange               0         40      19.58
# papaya              31         70      49.88
# pigeonpeas           0         40      20.73
# pomegranate          0         40      18.87
# rice                60         99      79.89
# watermelon          80        120      99.42

# %%
nitrogen.reset_index(inplace=True)

# %%
# sns.set(rc('figure.figsize':(8,18)))
sns.catplot(x='label',y='avg_nitro',data=nitrogen,kind='bar',ec='k',color='g')

plt.xticks(rotation=270)


plt.show()

# %%
# plt.figure(figsize=(10,10))
# plt.bar()

# %%
# sns.set(rc('figure.figsize':(8,18)))
sns.catplot(x='label',y='min_nitro',data=nitrogen,kind='bar',ec='k',color='g')

plt.xticks(rotation=270)


plt.show()

# %%
crops_label=list(nitrogen['label'])
avg_nitrogen=list(nitrogen['avg_nitro'])
plt.pie(avg_nitrogen,labels=crops_label,autopct='%2.2f%%')
plt.figure(figsize=(24,24))
plt.show()

# %%
crops_label=list(nitrogen['label'])
min_nitrogen=list(nitrogen['min_nitro'])
plt.pie(min_nitrogen,labels=crops_label,autopct='%2.2f%%')
plt.figure(figsize=(24,24))
plt.show()

# %%
crops_label=list(nitrogen['label'])
max_nitrogen=list(nitrogen['max_nitro'])
plt.pie(max_nitrogen,labels=crops_label,autopct='%2.2f%%',wedgeprops={'ec':'k'})
plt.figure(figsize=(24,24))
plt.show()

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
rainfall=group['rainfall'].agg(min_rainfall='min',max_rainfall='max',avg_rainfall='mean')

# %%
rainfall.reset_index()
# Out:
#           label  min_rainfall  max_rainfall  avg_rainfall
# 0         apple    100.117344    124.983162    112.654779
# 1        banana     90.109781    119.847970    104.626980
# 2     blackgram     60.417903     74.915595     67.884151
# 3      chickpea     65.113656     94.781896     80.058977
# 4       coconut    131.090008    225.632366    175.686646
# 5        coffee    115.156401    199.473564    158.066295
# 6        cotton     60.653817     99.931008     80.398043
# 7        grapes     65.010953     74.915062     69.611829
# 8          jute    150.235524    199.836291    174.792798
# 9   kidneybeans     60.275525    149.744103    105.919778
# 10       lentil     35.034848     54.939377     45.680454
# 11        maize     60.651715    109.751538     84.766988
# 12        mango     89.291476    100.812466     94.704515
# 13    mothbeans     30.920140     74.443307     51.198487
# 14     mungbean     36.120429     59.872321     48.403601
# 15    muskmelon     20.211267     29.866814     24.689952
# 16       orange    100.173796    119.694658    110.474969
# 17       papaya     40.351531    248.859299    142.627839
# 18   pigeonpeas     90.054227    198.829881    149.457564
# 19  pomegranate    102.518476    112.475094    107.528442
# 20         rice    182.561632    298.560117    236.181114
# 21   watermelon     40.126504     59.759800     50.786219

# %%
temperature=group['temperature'].agg(min_temperature='min',max_temperature='max',avg_temperature='mean')

# %%
temperature.reset_index()
# Out:
#           label  min_temperature  max_temperature  avg_temperature
# 0         apple        21.036527        23.996862        22.630942
# 1        banana        25.010185        29.908885        27.376798
# 2     blackgram        25.097374        34.946616        29.973340
# 3      chickpea        17.024985        20.995022        18.872847
# 4       coconut        25.008724        29.869083        27.409892
# 5        coffee        23.059519        27.923744        25.540477
# 6        cotton        22.000851        25.992374        23.988958
# 7        grapes         8.825675        41.948657        23.849575
# 8          jute        23.094338        26.985822        24.958376
# 9   kidneybeans        15.330426        24.923601        20.115085
# 10       lentil        18.064861        29.944139        24.509052
# 11        maize        18.041855        26.549864        22.389204
# 12        mango        27.003155        35.990097        31.208770
# 13    mothbeans        24.018254        31.999286        28.194920
# 14     mungbean        27.014704        29.914544        28.525775
# 15    muskmelon        27.024151        29.943492        28.663066
# 16       orange        10.010813        34.906653        22.765725
# 17       papaya        23.012402        43.675493        33.723859
# 18   pigeonpeas        18.319104        36.977944        27.741762
# 19  pomegranate        18.071330        24.962732        21.837842
# 20         rice        20.045414        26.929951        23.689332
# 21   watermelon        24.043558        26.986037        25.591767

# %%
# sns.set(rc('figure.figsize':(8,18)))
sns.catplot(x='label',y='min_rainfall',data=rainfall,kind='bar',ec='k',color='g')

plt.xticks(rotation=270)


plt.show()

# %%
# sns.set(rc('figure.figsize':(8,18)))
sns.catplot(x='label',y='max_rainfall',data=rainfall,kind='bar',ec='k',color='g')

plt.xticks(rotation=270)


plt.show()

# %%
# sns.set(rc('figure.figsize':(8,18)))
sns.catplot(x='label',y='avg_rainfall',data=rainfall,kind='bar',ec='k',color='g')

plt.xticks(rotation=270)


plt.show()

# %%
## unsupervide x
x=df.drop('label',axis=1)
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.boxplot(df['N'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(2,2,1)
plt.boxplot(df['P'])
plt.show()

plt.subplot(2,2,2)
plt.boxplot(df['P'])
plt.show()

plt.subplot(2,2,3)
plt.boxplot(df['K'])
plt.show()

# %%
i=1
for col in x.columns:
    plt.subplot(i,3,3)
    plt.title(col)
    plt.boxplot(df[col])
    i+=1

plt.show()

# %%
# kMeans
from sklearn.preprocessing import MinMaxScaler,RobustScaler,StandardScaler,Normalizer
std=StandardScaler()
x_transformed=std.fit_transform(x)

# %%
x_transformed
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
x.shape
# Out:
# (2200, 7)

# %%
df['N'].mean()
# Out:
# np.float64(50.551818181818184)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans()
kmeans.fit(x_transformed)
#  euclidian distance method
# Out:
# KMeans()

# %%
np.unique(kmeans.labels_)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int32)

# %%
kmeans.labels_.shape,df.shape
# Out:
# ((2200,), (2200, 8))

# %%
df['cluster_no']=kmeans.labels_

# %%
df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label  cluster_no
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice           2
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice           2
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice           2
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice           2
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice           2
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice           2
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice           2
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice           2
