# %% [markdown]
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import sklearn as skl
import warnings
warnings.filterwarnings('ignore')
print("libraries imported")
# what is label encoding?
#  what is one hot encoding???
# _____assingment________work on this data and revise the backlog
# Out:
# libraries imported

# %%
df=pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# print("number of duplicated record",df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
print("NO.of duplicate records:",df.duplicated().sum())
# Out:
# NO.of duplicate records: 25324

# %%
df.drop_duplicates(inplace=True)
print("Duplicated removed")
# Out:
# Duplicated removed

# %%
print("total no.of duplicates records",df.duplicated().sum())
# Out:
# total no.of duplicates records 0

# %%
print("total no. of records",df.shape[0])
# Out:
# total no. of records 7324

# %%
# missing value check in your date
df.isnull().sum()


# Machine learning are purely numerical no categorical value should be given to them
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
cat_col=df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col=df.select_dtypes(exclude='O')
num_col.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
cat_col['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt={'First Owner':1,            
'Second Owner':2,             
'Third Owner':3,              
'Fourth Owner Or More':4

}
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner']=df['owner'].map(dt) #single time execute

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# 0         1  3.0  110.0              TVS
# 1         1  4.0  350.0    Royal Enfield
# 2         1  8.0  675.0          Triumph
# 3         1  4.0  180.0              TVS
# 4         1  3.0  150.0           Yamaha
# ...     ...  ...    ...              ...
# 9362      1  8.0  150.0             Hero
# 9369      1  9.0  220.0            Bajaj
# 9370      1  4.0  750.0  Harley-Davidson
# 9371      1  4.0  400.0            Bajaj
# 9372      1  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
# df['brand']=df['brand'].value_counts()>=10
# df['brand'].value_counts()

# %%
bike_brand=list(df['brand'].value_counts().head(16).index)
bike_brand
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
# (df['brand']=="Bajaj") |(df['brand']=="Royal Enfield")
df2=df[df['brand'].isin(bike_brand)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
df2['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Name: count, dtype: int64

# %%
ls=list(df2['brand'].value_counts().keys())

# %%
for i in range(len(df2['brand'].value_counts())):
    dt[ls[i]]=i+1

# %%
df2['brand']= df2['brand'].map(dt)

# %%
df2.drop(['bike_name','city'],axis='columns',inplace=True)

# %%
df2.head()
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      6
# 1  119900.0     11000.0      1  4.0  350.0      2
# 2  600000.0       110.0      1  8.0  675.0     14
# 3   65000.0     16329.0      1  4.0  180.0      6
# 4   80000.0     10000.0      1  3.0  150.0      5

# %% [markdown]
# # splitting data independent and dependent variables

# %%
x=df2.drop('price',axis='columns')
y=df2[['price']]

# %%
x.head()
# Out:
#    kms_driven  owner  age  power  brand
# 0     17654.0      1  3.0  110.0      6
# 1     11000.0      1  4.0  350.0      2
# 2       110.0      1  8.0  675.0     14
# 3     16329.0      1  4.0  180.0      6
# 4     10000.0      1  3.0  150.0      5

# %%
from sklearn.model_selection import train_test_split

# %%
df2['brand'].head(17)
# Out:
# 0      6
# 1      2
# 2     14
# 3      6
# 4      5
# 5      5
# 6      4
# 7      3
# 8      2
# 9      2
# 10     5
# 11     5
# 12     1
# 13     1
# 14     1
# 15     1
# 16     1
# Name: brand, dtype: int64

# %% [markdown]
# ### splitting data independent and dependent variables

# %%
x=df2.drop('price',axis='columns') #dependent variables
y=df2[['price']] # independent variable or target variable

# %%
x.head()
# Out:
#    kms_driven  owner  age  power  brand
# 0     17654.0      1  3.0  110.0      6
# 1     11000.0      1  4.0  350.0      2
# 2       110.0      1  8.0  675.0     14
# 3     16329.0      1  4.0  180.0      6
# 4     10000.0      1  3.0  150.0      5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2) #test  size 20%

# %%
from sklearn.linear_model import LinearRegression

# %%
# instance creatiion
lnr =LinearRegression()

# %%
# algorithm train
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model evaluation

# %%
print("Training score:",lnr.score(x_train,y_train)*100)
print("testing score:",lnr.score(x_test,y_test)*100)
# Out:
# Training score: 75.2760309768559
# testing score: 69.2303551605639

# %%
x_test.shape
# total bikes
# Out:
# (1462, 5)

# %%
y_test
# Out:
#          price
# 1251  250000.0
# 2145   62700.0
# 2748  192000.0
# 6660  115000.0
# 4800   30000.0
# ...        ...
# 8683   20000.0
# 1413   30900.0
# 3105   57000.0
# 7760   39000.0
# 7455   25000.0
#
# [1462 rows x 1 columns]

# %%
prediction =lnr.predict(x_test)

# %%
prediction.shape
# Out:
# (1462, 1)

# %%
y_test
# Out:
#          price
# 1251  250000.0
# 2145   62700.0
# 2748  192000.0
# 6660  115000.0
# 4800   30000.0
# ...        ...
# 8683   20000.0
# 1413   30900.0
# 3105   57000.0
# 7760   39000.0
# 7455   25000.0
#
# [1462 rows x 1 columns]

# %%
comparedf =pd.concat([x_test,y_test],axis=1)

# %%
comparedf['prediction']=prediction

# %%
comparedf.head(40)
# Out:
#       kms_driven  owner   age  power  brand     price     prediction
# 1251       920.0      1   2.0  650.0      2  250000.0  307085.205397
# 2145      5678.0      3   9.0  250.0      4   62700.0   84605.258973
# 2748      7390.0      1   6.0  250.0     11  192000.0  187852.958897
# 6660      3300.0      1   5.0  410.0      2  115000.0  170971.112883
# 4800     27000.0      1  12.0  150.0      5   30000.0   46883.239910
# 3912     33505.0      1   3.0  100.0      1   35000.0   -3338.888408
# 6924     45000.0      1   7.0  180.0      1   45000.0   27789.189600
# 5669     11300.0      1   4.0  200.0      1   77000.0   49245.213240
# 2543     37248.0      1  11.0  220.0      1   26800.0   39225.453225
# 7262     21007.0      1   9.0  150.0      5   14000.0   55311.590997
# 7476     45000.0      1   5.0  320.0      5  250000.0  154485.544254
# 9315      5000.0      1  10.0  100.0      3   20000.0    3993.868004
# 7931     10000.0      1   6.0  500.0      2  150000.0  215758.503894
# 6689     32000.0      2  63.0  350.0      2   70000.0  -23373.587401
# 227      16000.0      1   4.0  350.0      2  105000.0  140529.425467
# 6063     12308.0      1   7.0  125.0      4   35000.0   36309.970046
# 9283      5600.0      1   4.0  200.0      1  120000.0   49731.037501
# 8369     10334.0      1   5.0  883.0      9  700000.0  504447.064825
# 2423     30000.0      2  12.0  350.0      2   82000.0  111395.291087
# 3071       893.0      1   2.0  160.0      6   94000.0   92522.066869
# 8005     15000.0      2   5.0  390.0      7  130000.0  210924.101658
# 5573     37000.0      1   8.0  100.0      1   22000.0  -16832.698314
# 1249     80000.0      1  14.0  350.0      2   75700.0  108682.710727
# 7876      8089.0      1   5.0  150.0      1   56000.0   20214.358442
# 6340     26885.0      1   5.0  150.0      1   39000.0   18612.331635
# 2561     16873.0      1   5.0  150.0      1   47000.0   19465.677687
# 5049     47000.0      1  10.0  150.0      1   35000.0    3701.960465
# 5849     89999.0      1   4.0  100.0      3   26365.0   12584.313002
# 2158     15000.0      1   9.0  500.0      2  150000.0  207414.788507
# 6726     15000.0      2   3.0  125.0      4   55000.0   39809.857834
# 456       7500.0      1   4.0  400.0      1  140000.0  156230.500932
# 1726      3086.0      1   3.0  150.0      5   71400.0   72674.147028
# 1284     11000.0      1   5.0  350.0      2  133300.0  138316.402514
# 7434     29800.0      1   7.0  150.0      5   50000.0   59840.512321
# 1933      8000.0      1   5.0  150.0      1   70000.0   20221.944119
# 7667     25000.0      1  12.0  200.0      1   25000.0   26964.053688
# 8377      7500.0      1   5.0  150.0      8   70000.0  102085.813935
# 8563     28000.0      1   8.0  500.0      2  101001.0  208945.952849
# 5691     79004.0      1   7.0  125.0      4   30000.0   30625.314804
# 759      53000.0      1   5.0  160.0      4   39300.0   56785.811239

# %%
comparedf['residual']=
# Out:
#   Cell In[46], line 1
#     comparedf['residual']=
#                           ^
# SyntaxError: invalid syntax

# %%
comparedf['price']- comparedf['prediction']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[332], line 1
# ----> 1 comparedf['price']- comparedf['prediction']
#
# NameError: name 'comparedf' is not defined

# %%
comparedf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[363], line 1
# ----> 1 comparedf.head()
#
# NameError: name 'comparedf' is not defined

# %%
# prediction
unseen_bike=[[3500,2,2,2,3]]
price_of_unseen_bike=lnr.predict(unseen_bike)
price_of_unseen_bike
# Out:
# C:\Users\tanma\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[364], line 3
#       1 # prediction
#       2 unseen_bike=[[3500,2,2,2,3]]
# ----> 3 price_of_unseen_bike=lnr.predict(unseen_bike)
#       4 price_of_unseen_bike
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:286, in LinearModel._decision_function(self, X)
#     283 check_is_fitted(self)
#     285 X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 286 coef_ = self.coef_
#     287 if coef_.ndim == 1:
#     288     return X @ coef_ + self.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
x_train
# Out:
#       kms_driven  owner   age   power  brand
# 4551     12552.0      1   3.0   350.0    NaN
# 3175      7000.0      1   2.0   160.0    NaN
# 6255     14088.0      1   3.0   150.0    NaN
# 8481     40000.0      1   5.0   100.0    NaN
# 2264       152.0      1   5.0  1000.0    NaN
# ...          ...    ...   ...     ...    ...
# 5565     15000.0      1   5.0   150.0    NaN
# 4513     50444.0      1  10.0   150.0    NaN
# 5968     36578.0      1  10.0   100.0    NaN
# 7490     13551.0      1   4.0   150.0    NaN
# 8434     38000.0      1   9.0   350.0    NaN
#
# [5845 rows x 5 columns]

# %% [markdown]
# #saving models

# %%
import os,joblib

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1628-5EA5
#
#  Directory of c:\Users\tanma\.vscode\upflaire\DATA-SCIENCE-WITH-GENERATIVE-AI-AND-PROMPT-ENGINEERING\Machine learning
#
# 27-07-2024  10:44    <DIR>          .
# 27-07-2024  10:10    <DIR>          ..
# 29-07-2024  11:51           100,649 project1.ipynb
# 18-07-2024  10:10         2,493,547 Used_Bikes.csv
#                2 File(s)      2,594,196 bytes
#                2 Dir(s)  366,347,354,112 bytes free

# %%
os.makedirs('models',exit_ok=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[368], line 1
# ----> 1 os.makedirs('models',exit_ok=True)
#
# NameError: name 'os' is not defined

# %%
student_ls=['mohan','rohan','sohan','manmohan']
student_ls
# Out:
# ['mohan', 'rohan', 'sohan', 'manmohan']

# %%
joblib.dump(student_ls,'studentList.lb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[430], line 1
# ----> 1 joblib.dump(student_ls,'studentList.lb')
#
# NameError: name 'joblib' is not defined

# %%
joblib.load(studentList.lb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[431], line 1
# ----> 1 joblib.load(studentList.lb)
#
# NameError: name 'joblib' is not defined

# %%
joblib.dump(lnr,'./models/linearRegression.lb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[432], line 1
# ----> 1 joblib.dump(lnr,'./models/linearRegression.lb')
#
# NameError: name 'joblib' is not defined

# %%
joblib.load(lnr,'./models/linearRegression.lb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[463], line 1
# ----> 1 joblib.load(lnr,'./models/linearRegression.lb')
#
# NameError: name 'joblib' is not defined
