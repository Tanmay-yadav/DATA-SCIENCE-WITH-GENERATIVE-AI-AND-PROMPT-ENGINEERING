# %%
# date 23rd july
# _________make assingment--> make panda ,numpy,matplotlib jupyter notebook and upflaires git 
# repository and post all these on github and linkedin 
# make ppt on everything about  this course and a project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("libraries imported!")
# Out:
# libraries imported!

# %% [markdown]
# # SEABORN

# %%
# seaborn is an extended versiion of matplot lib

# %%
# sns.barplot()
# sns.scatterplot()
# sns.lineplot()
# sns.histplot()
# sns.boxplot()

# %%
df=pd.read_csv('Used_Bikes.csv')
df.head()

# %%
brand_name=list(df['brand'].value_counts().keys())
bike_count=list(df['brand'].value_counts().values)

# %%
plt.bar(brand_name,bike_count)
plt.xticks(rotation=270)
plt.show()

# %%
brand_name = list(df['brand'].value_counts().keys())
bike_count = list(df['brand'].value_counts().values)

# %%
sns.barplot(x=brand_name,y=bike_count)
plt.xticks(rotation=270)
plt.show()

# %%
sns.barplot(x=brand_name,y=bike_count)
plt.xticks(rotation=270)
plt.show()

# %% [markdown]
# ### - relplot()-->relational plot{used when both the columns  are numerical}
# ### - catplot()-->categorical plot{when only one of them is numerical }

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker',col='day')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='time',style='smoker',col='day')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')# to ignore warnings

# %%
sns.relplot(x='size',y='total_bill',data=df,col='day',kind='line')
plt.show()
# relational plot,scatter,line plot

# %% [markdown]
# # categoraical plot

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='point')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='swarm')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='violin')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='boxen')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='strip')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='strip')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='box')
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue='sex',kind='bar')
plt.show()

# %%
sns.catplot(x="smoker",data=df,hue='sex',kind='count')
plt.show()

# %%
# tasks--->sns.load_dataset('titanic')
# work all charts and analysis on this dataset
# sns.load_dataset('iris')

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot(x='sepal_length',y='sepal_width',data=df)
plt.show()
